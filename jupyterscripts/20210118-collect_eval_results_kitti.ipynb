# %%
# load libs
from det3.ops import read_pkl
from incdet3.utils.utils import filt_label_by_range

# %%
# global variables
g_info_pkl_path = "/usr/app/data/KITTI/KITTI_infos_val.pkl"
g_valid_range = [0, -32.0, -3, 52.8, 32.0, 1]
g_valid_classes_dict = {
    "old": ["Car", "Pedestrian"],
    "new": ["Cyclist", "Van", "Truck"],
    "all": ["Car", "Pedestrian", "Cyclist", "Van", "Truck"]
}
g_case2evalresult = {
#     "A1to2": {
#         "old": "/usr/app/incdet3/logs/20210118-expkitti2+3-A1to2old-eval/test_results.pkl"
#     },
#     "A1to5": {
#         "old": "/usr/app/incdet3/logs/20210118-expkitti2+3-A1to5old-eval/test_results.pkl",
#         "new": "/usr/app/incdet3/logs/20210118-expkitti2+3-A1to5new-eval/test_results.pkl",
#         "all": "/usr/app/incdet3/logs/20210118-expkitti2+3-A1to5all-eval/test_results.pkl",
#     },
#     "B(3-5)finetune": {
#         "old": "/usr/app/incdet3/logs/20210118-expkitti2+3-B3to5finetuningold-eval/test_results.pkl",
#         "new": "/usr/app/incdet3/logs/20210118-expkitti2+3-B3to5finetuningnew-eval/test_results.pkl",
#         "all": "/usr/app/incdet3/logs/20210118-expkitti2+3-B3to5finetuningall-eval/test_results.pkl",
#     },
#     "B(3-5)ewc": {
#         "old": "/usr/app/incdet3/logs/20210118-expkitti2+3-B3to5ewcold-eval/test_results.pkl",
#         "new": "/usr/app/incdet3/logs/20210118-expkitti2+3-B3to5ewcnew-eval/test_results.pkl",
#         "all": "/usr/app/incdet3/logs/20210118-expkitti2+3-B3to5ewcall-eval/test_results.pkl",
#     },
#     "B(3-5)mas": {
#         "old": "/usr/app/incdet3/logs/20210118-expkitti2+3-B3to5masold-eval/test_results.pkl",
#         "new": "/usr/app/incdet3/logs/20210118-expkitti2+3-B3to5masnew-eval/test_results.pkl",
#         "all": "/usr/app/incdet3/logs/20210118-expkitti2+3-B3to5masall-eval/test_results.pkl",
#     },
#     "B(3-5)kd unbiased": {
#         "old": "/usr/app/incdet3/logs/20210118-expkitti2+3-B3to5lwfunbiasedold-eval/test_results.pkl",
#         "new": "/usr/app/incdet3/logs/20210118-expkitti2+3-B3to5lwfunbiasednew-eval/test_results.pkl",
#         "all": "/usr/app/incdet3/logs/20210118-expkitti2+3-B3to5lwfunbiasedall-eval/test_results.pkl",
#     },
#     "B(3-5)kd threshold": {
#         "old": "/usr/app/incdet3/logs/20210118-expkitti2+3-B3to5lwfthresholdold-eval/test_results.pkl",
#         "new": "/usr/app/incdet3/logs/20210118-expkitti2+3-B3to5lwfthresholdnew-eval/test_results.pkl",
#         "all": "/usr/app/incdet3/logs/20210118-expkitti2+3-B3to5lwfthresholdall-eval/test_results.pkl",
#     },
#     "B(3-5)kd": {
#         "old": "/usr/app/incdet3/logs/20210118-expkitti2+3-B3to5lwfold-eval/test_results.pkl",
#         "new": "/usr/app/incdet3/logs/20210118-expkitti2+3-B3to5lwfnew-eval/test_results.pkl",
#         "all": "/usr/app/incdet3/logs/20210118-expkitti2+3-B3to5lwfall-eval/test_results.pkl",
#     },
#     "B(3-5)incdet": {
#         "old": "/usr/app/incdet3/logs/20210118-expkitti2+3-B3to5pseudoewcold-eval/test_results.pkl",
#         "new": "/usr/app/incdet3/logs/20210118-expkitti2+3-B3to5pseudoewcnew-eval/test_results.pkl",
#         "all": "/usr/app/incdet3/logs/20210118-expkitti2+3-B3to5pseudoewcall-eval/test_results.pkl",
#     },
#     "B(3-5)ckdewc": {
#         "old": "/usr/app/incdet3/logs/20210118-expkitti2+3-B3to5kdewcold-eval/test_results.pkl",
#         "new": "/usr/app/incdet3/logs/20210118-expkitti2+3-B3to5kdewcnew-eval/test_results.pkl",
#         "all": "/usr/app/incdet3/logs/20210118-expkitti2+3-B3to5kdewcall-eval/test_results.pkl",
#     },
#     "B(3-5)ckdmas": {
#         "old": "/usr/app/incdet3/logs/20210118-expkitti2+3-B3to5kdmasold-eval/test_results.pkl",
#         "new": "/usr/app/incdet3/logs/20210118-expkitti2+3-B3to5kdmasnew-eval/test_results.pkl",
#         "all": "/usr/app/incdet3/logs/20210118-expkitti2+3-B3to5kdmasall-eval/test_results.pkl",
#     },
#     "B(3-5)joint": {
#         "old": "/usr/app/incdet3/logs/20210118-expkitti2+3-B3to5jointtrainingold-eval/test_results.pkl",
#         "new": "/usr/app/incdet3/logs/20210118-expkitti2+3-B3to5jointtrainingnew-eval/test_results.pkl",
#         "all": "/usr/app/incdet3/logs/20210118-expkitti2+3-B3to5jointtrainingall-eval/test_results.pkl",
#     },
    #
    "B(3)(4)(5)finetune": {
        "old": "/usr/app/incdet3/logs/20210118-expkitti2+seq-B3to5finetuningold-eval/test_results.pkl",
        "new": "/usr/app/incdet3/logs/20210118-expkitti2+seq-B3to5finetuningnew-eval/test_results.pkl",
        "all": "/usr/app/incdet3/logs/20210118-expkitti2+seq-B3to5finetuningall-eval/test_results.pkl",
    },
    "B(3)(4)(5)ewc": {
        "old": "/usr/app/incdet3/logs/20210118-expkitti2+seq-B3to5ewcold-eval/test_results.pkl",
        "new": "/usr/app/incdet3/logs/20210118-expkitti2+seq-B3to5ewcnew-eval/test_results.pkl",
        "all": "/usr/app/incdet3/logs/20210118-expkitti2+seq-B3to5ewcall-eval/test_results.pkl",
    },
    "B(3)(4)(5)mas": {
        "old": "/usr/app/incdet3/logs/20210118-expkitti2+seq-B3to5masold-eval/test_results.pkl",
        "new": "/usr/app/incdet3/logs/20210118-expkitti2+seq-B3to5masnew-eval/test_results.pkl",
        "all": "/usr/app/incdet3/logs/20210118-expkitti2+seq-B3to5masall-eval/test_results.pkl",
    },
    "B(3)(4)(5)kd unbiased": {
        "old": "/usr/app/incdet3/logs/20210118-expkitti2+seq-B3to5lwfunbiasedold-eval/test_results.pkl",
        "new": "/usr/app/incdet3/logs/20210118-expkitti2+seq-B3to5lwfunbiasednew-eval/test_results.pkl",
        "all": "/usr/app/incdet3/logs/20210118-expkitti2+seq-B3to5lwfunbiasedall-eval/test_results.pkl",
    },
    "B(3)(4)(5)kd threshold": {
        "old": "/usr/app/incdet3/logs/20210118-expkitti2+seq-B3to5lwfthresholdold-eval/test_results.pkl",
        "new": "/usr/app/incdet3/logs/20210118-expkitti2+seq-B3to5lwfthresholdnew-eval/test_results.pkl",
        "all": "/usr/app/incdet3/logs/20210118-expkitti2+seq-B3to5lwfthresholdall-eval/test_results.pkl",
    },
    "B(3)(4)(5)kd": {
        "old": "/usr/app/incdet3/logs/20210118-expkitti2+seq-B3to5lwfold-eval/test_results.pkl",
        "new": "/usr/app/incdet3/logs/20210118-expkitti2+seq-B3to5lwfnew-eval/test_results.pkl",
        "all": "/usr/app/incdet3/logs/20210118-expkitti2+seq-B3to5lwfall-eval/test_results.pkl",
    },
    "B(3)(4)(5)incdet": {
        "old": "/usr/app/incdet3/logs/20210118-expkitti2+seq-B3to5pseudoewcold-eval/test_results.pkl",
        "new": "/usr/app/incdet3/logs/20210118-expkitti2+seq-B3to5pseudoewcnew-eval/test_results.pkl",
        "all": "/usr/app/incdet3/logs/20210118-expkitti2+seq-B3to5pseudoewcall-eval/test_results.pkl",
    },
    "B(3)(4)(5)ckdewc": {
        "old": "/usr/app/incdet3/logs/20210118-expkitti2+seq-B3to5kdewcold-eval/test_results.pkl",
        "new": "/usr/app/incdet3/logs/20210118-expkitti2+seq-B3to5kdewcnew-eval/test_results.pkl",
        "all": "/usr/app/incdet3/logs/20210118-expkitti2+seq-B3to5kdewcall-eval/test_results.pkl",
    },
    "B(3)(4)(5)ckdmas": {
        "old": "/usr/app/incdet3/logs/20210118-expkitti2+seq-B3to5kdmasold-eval/test_results.pkl",
        "new": "/usr/app/incdet3/logs/20210118-expkitti2+seq-B3to5kdmasnew-eval/test_results.pkl",
        "all": "/usr/app/incdet3/logs/20210118-expkitti2+seq-B3to5kdmasall-eval/test_results.pkl",
    },
    "B(3)(4)(5)joint": {
        "old": "/usr/app/incdet3/logs/20210118-expkitti2+seq-B3to5jointtrainingold-eval/test_results.pkl",
        "new": "/usr/app/incdet3/logs/20210118-expkitti2+seq-B3to5jointtrainingnew-eval/test_results.pkl",
        "all": "/usr/app/incdet3/logs/20210118-expkitti2+seq-B3to5jointtrainingall-eval/test_results.pkl",
    },
}
g_config_dict = {
    "Car": "3d@0.50",
    "Pedestrian": "3d@0.25",
    "Cyclist": "3d@0.25",
    "Van": "3d@0.50",
    "Truck": "3d@0.50",
}

# %%
# define functions
def compute_acc_dict(info_pkl, valid_range, valid_classes):
    # compute num of cars and num of pedes
    acc_dict = {itm: 0 for itm in valid_classes}
    ## load val pkl
    for itm in info_pkl:
        label = itm['label']
        calib = itm['calib']
        label_ = filt_label_by_range(label, valid_range, calib)
        if len(label_) == 0:
            continue
        has_classes = [obj.type for obj in label_.data]
        has_classes = list(set(has_classes))
        for cls in has_classes:
            if cls in valid_classes:
                acc_dict[cls] += 1
    return acc_dict
    
def compute_mAP(eval_result, acc_dict):
    data = eval_result['detail']
    valid_classes = [itm for itm in acc_dict.keys()]
    calc_map_dict = {itm: None for itm in valid_classes}
    for cls in valid_classes:
        eval_attrib = g_config_dict[cls]
        calc_map_dict[cls] = data[cls][eval_attrib]
    map_val = 0
    for cls in valid_classes:
        mean_ap = sum(calc_map_dict[cls]) / len(calc_map_dict[cls])
        cls_norm = acc_dict[cls] / sum([v for k, v in acc_dict.items()])
        map_val += mean_ap * cls_norm
    return map_val

# %%
# compute old-task mAP
## A(1-4)
## B(5)_finetuning
## B(5)_jointtraining
## B(5)_lwf
task = "old"
info_pkl_path = g_info_pkl_path
valid_range = g_valid_range
valid_classes = g_valid_classes_dict[task]
case_list = g_case2evalresult.keys()

info_pkl = read_pkl(info_pkl_path)
acc_dict = compute_acc_dict(info_pkl, valid_range, valid_classes)
print(acc_dict)
old_mAP_dict = {}
for case in case_list:
    if g_case2evalresult[case][task] is None:
        continue
    eval_result = read_pkl(g_case2evalresult[case][task])
    old_mAP = compute_mAP(eval_result, acc_dict)
    old_mAP_dict[case] = old_mAP
for k, v in old_mAP_dict.items():
    print(f"{k},{v:.1f}")
# Out:
# {'Car': 3277, 'Pedestrian': 802}
# B(3)(4)(5)finetune,0.0
# B(3)(4)(5)ewc,0.0
# B(3)(4)(5)mas,0.0
# B(3)(4)(5)kd unbiased,0.0
# B(3)(4)(5)kd threshold,66.8
# B(3)(4)(5)kd,67.8
# B(3)(4)(5)incdet,75.3
# B(3)(4)(5)ckdewc,79.3
# B(3)(4)(5)ckdmas,81.8
# B(3)(4)(5)joint,83.8

# %%
# compute new-task mAP
## A(1-4)
## B(5)_finetuning
## B(5)_jointtraining
## B(5)_lwf
task = "new"
info_pkl_path = g_info_pkl_path
valid_range = g_valid_range
valid_classes = g_valid_classes_dict[task]
case_list = g_case2evalresult.keys()

info_pkl = read_pkl(info_pkl_path)
acc_dict = compute_acc_dict(info_pkl, valid_range, valid_classes)
new_mAP_dict = {}
print(acc_dict)
for case in case_list:
    eval_result_path = g_case2evalresult[case][task]
    if eval_result_path is None:
        continue
    eval_result = read_pkl(eval_result_path)
    new_mAP = compute_mAP(eval_result, acc_dict)
    new_mAP_dict[case] = new_mAP
for k, v in new_mAP_dict.items():
    print(f"{k},{v:.1f}")
# Out:
# {'Cyclist': 573, 'Van': 1020, 'Truck': 215}
# B(3)(4)(5)finetune,0.0
# B(3)(4)(5)ewc,0.9
# B(3)(4)(5)mas,0.8
# B(3)(4)(5)kd unbiased,0.3
# B(3)(4)(5)kd threshold,27.9
# B(3)(4)(5)kd,33.5
# B(3)(4)(5)incdet,25.9
# B(3)(4)(5)ckdewc,37.8
# B(3)(4)(5)ckdmas,39.2
# B(3)(4)(5)joint,29.4

# %%
# compute all mAP
## A(1-4)
## B(5)_finetuning
## B(5)_jointtraining
## B(5)_lwf
task = "all"
info_pkl_path = g_info_pkl_path
valid_range = g_valid_range
valid_classes = g_valid_classes_dict[task]
case_list = g_case2evalresult.keys()

info_pkl = read_pkl(info_pkl_path)
acc_dict = compute_acc_dict(info_pkl, valid_range, valid_classes)
all_mAP_dict = {}
print(acc_dict)
for case in case_list:
    eval_result_path = g_case2evalresult[case][task]
    if eval_result_path is None:
        continue
    eval_result = read_pkl(eval_result_path)
    all_mAP = compute_mAP(eval_result, acc_dict)
    all_mAP_dict[case] = all_mAP
for k, v in all_mAP_dict.items():
    print(f"{k},{v:.1f}")
# Out:
# {'Car': 3277, 'Pedestrian': 802, 'Cyclist': 573, 'Van': 1020, 'Truck': 215}
# B(3)(4)(5)finetune,0.0
# B(3)(4)(5)ewc,0.2
# B(3)(4)(5)mas,0.1
# B(3)(4)(5)kd unbiased,0.1
# B(3)(4)(5)kd threshold,53.3
# B(3)(4)(5)kd,55.4
# B(3)(4)(5)incdet,58.7
# B(3)(4)(5)ckdewc,65.2
# B(3)(4)(5)ckdmas,66.8
# B(3)(4)(5)joint,65.3
